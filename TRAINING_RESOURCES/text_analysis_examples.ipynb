# %% [markdown]
# # DS4DD training: text analysis
#
# this is a comment

# %% [markdown]
# ## Grab dataset

# %%
import pandas as pd
import json
from sklearn.feature_extraction.text import CountVectorizer

def sort_words_by_count(word_counts, feature_names):
    df = pd.DataFrame(word_counts.A, columns=feature_names).transpose()
    df.columns = ['count']
    df = df.sort_values(by='count', ascending=False)
    return df


# Read dataset into a Pandas dataframe
infile = '../data/twitter/20200711140613_covid-5g/20200711140613_covid-5g_tweets.json'
with open(infile) as json_file:
    jdata = json.load(json_file)
df = pd.DataFrame.from_dict(jdata, orient='index')
df.reset_index(level=0, inplace=True)
df.columns = ['url', 'text']
df
# Out:
#                                                     url  \
# 0     https://twitter.com/quintamistico/status/12820...
# 1     https://twitter.com/Sparta2427/status/12820584...
# 2     https://twitter.com/kayfabe25/status/128205832...
# 3     https://twitter.com/Fher69Rojas_/status/128205...
# 4     https://twitter.com/hearnlp/status/12820577962...
# 5     https://twitter.com/WilmaRubble3/status/128205...
# 6     https://twitter.com/phillyfangirl/status/12820...
# 7     https://twitter.com/tryst_me/status/1282056124...
# 8     https://twitter.com/booouille/status/128205603...
# 9     https://twitter.com/MegaloSoto/status/12820559...
# 10    https://twitter.com/Healinguru/status/12820559...
# 11    https://twitter.com/JPLFR80/status/12820556125...
# 12    https://twitter.com/BobTheSuit/status/12820555...
# 13    https://twitter.com/Smokemi43260487/status/128...
# 14    https://twitter.com/Sawallef6/status/128205521...
# 15    https://twitter.com/ohdonny_/status/1282054957...
# 16    https://twitter.com/Pythago38919500/status/128...
# 17    https://twitter.com/IAM__Network/status/128205...
# 18    https://twitter.com/DanCabannas/status/1282053...
# 19    https://twitter.com/PahanaRay/status/128205375...
# 20    https://twitter.com/Dahl_Consult/status/128205...
# 21    https://twitter.com/robotmoth/status/128205350...
# 22    https://twitter.com/mikerestorer/status/128205...
# 23    https://twitter.com/lailr85/status/12820534077...
# 24    https://twitter.com/Shannon89558046/status/128...
# 25    https://twitter.com/Alfredinik/status/12820533...
# 26    https://twitter.com/LordCarda/status/128205280...
# 27    https://twitter.com/weed4pundits/status/128205...
# 28    https://twitter.com/ArenasJoseLuis4/status/128...
# 29    https://twitter.com/Mareq16/status/12820525476...
# ...                                                 ...
# 3804  https://twitter.com/NoobcleaverTV/status/12808...
# 3805  https://twitter.com/Stargazeer14/status/128086...
# 3806  https://twitter.com/saschirulo/status/12808653...
# 3807  https://twitter.com/Bwjw0373Wiles/status/12808...
# 3808  https://twitter.com/GRANNYBOYS16/status/128086...
# 3809  https://twitter.com/ConstructechMag/status/128...
# 3810  https://twitter.com/thewaterflea/status/128086...
# 3811  https://twitter.com/BlueRos10479662/status/128...
# 3812  https://twitter.com/lilicarmen78163/status/128...
# 3813  https://twitter.com/Mica4711/status/1280863671...
# 3814  https://twitter.com/Thomas_Binder/status/12808...
# 3815  https://twitter.com/c_williamsf/status/1280862...
# 3816  https://twitter.com/GEPC/status/12808620898469...
# 3817  https://twitter.com/mizzmana/status/1280860583...
# 3818  https://twitter.com/erictoulorge/status/128086...
# 3819  https://twitter.com/AGenetet/status/1280860491...
# 3820  https://twitter.com/AmbassadeChine/status/1280...
# 3821  https://twitter.com/SophieMette1/status/128085...
# 3822  https://twitter.com/TripZarbi/status/128085807...
# 3819  RT @BuonTAN: Ravi de ce temps d’échanges entre...
# 3820  RT @BuonTAN: Ravi de ce temps d’échanges entre...
# 3821  RT @BuonTAN: Ravi de ce temps d’échanges entre...
# 3822  RT @ComplotsFaciles: C'est fou, la 5G continue...
# 3823  Ravi de ce temps d’échanges entre le groupe d’...
# 3824  We join @ericsson​'s very own @LuckyLaRiccia l...
# 3825  RT @Inkazakhstanwe1: In Kazakhstan we don’t sa...
# 3826  Leicester going back into lockdown has nothing...
# 3827  @Mike_IMC @DavidLiPeng Sir ; COVID-19 is not s...
# 3828  @navedelmisterio Hace dos semanas, en Valencia...
# 3829  @PeacockGunnar I'm saying it doesn't matter if...
# 3830  In South East Asia and Oceania, 5G will accoun...
# 3831  @ImraneBensadok @LSfromLux @dr_l_alexandre Les...
# 3832  Vi lá no Hatebook que as antenas de 5G estão e...
# 3833                            https://t.co/cVMhHOfdVf
#
# [3834 rows x 2 columns]

# %% [markdown]
# ## Analyse all the text as one big string

# %%
# Let's have a look at *all* the tweets together... 
alltext = [' '.join(df['text'].to_list())]
alltext[0][:1000]
# Out:
# "RT @Loli99704518: @francis66675984 @rafapal Pues sí. Ya podríamos los españoles tomar ejemplo de los serbios. El covid forma parte de un en… RT @KateShemirani: Oh really? Just like with radiation poisoning then. Put enough symptoms down on the diagnosis sheet and you can just abo… RT @KateShemirani: Oh really? Just like with radiation poisoning then. Put enough symptoms down on the diagnosis sheet and you can just abo… @AlbertoRodNews Recordemos #5Jul Día de la independencia y brote del COVID-5G en un desfile sin tapabocas, pensaron que el uniforme era inmune 🧫 RT @KateShemirani: Oh really? Just like with radiation poisoning then. Put enough symptoms down on the diagnosis sheet and you can just abo… RT @Walletwalking1: @Sterling2143 @AAureilus Anyone noticed COVID symptoms are same as 5G exposure. What have they been rolling out in the… RT @ADDiane: Let's tell the people who won't wear masks that it's not for covid, it's for tricking the facial recognition software that dee… Discourse "

# %%
count_vect = CountVectorizer()
word_counts = count_vect.fit_transform(alltext)

print('{}'.format(word_counts))
# Out:
#   (0, 2849)	1
#   (0, 9086)	1
#   (0, 745)	1
#   (0, 2300)	1
#   (0, 12174)	1
#   (0, 12113)	1
#   (0, 7931)	1
#   (0, 7223)	1
#   (0, 2815)	1
#   (0, 6676)	1
#   (0, 9153)	1
#   (0, 8663)	1
#   (0, 12205)	1
#   (0, 2386)	1
#   (0, 10849)	1
#   (0, 957)	2
#   (0, 8143)	1
#   (0, 4760)	1
#   (0, 10591)	1
#   (0, 6799)	1
#   (0, 5609)	1
#   (0, 7998)	1
#   (0, 1957)	1
#   (0, 5623)	1
#   (0, 8480)	1
#   :	:
#   (0, 6644)	124
#   (0, 6172)	141
#   (0, 9484)	54
#   (0, 8102)	31
#   (0, 6234)	12
#   (0, 3830)	223
#   (0, 11759)	134
#   (0, 8402)	10
#   (0, 4528)	7
#   (0, 2657)	3173
#   (0, 3737)	512
#   (0, 10225)	5
#   (0, 2983)	1181
#   (0, 3731)	5
#   (0, 11432)	5
#   (0, 3993)	4
#   (0, 6768)	484
#   (0, 8762)	4
#   (0, 12558)	51
#   (0, 11002)	13
#   (0, 9172)	8
#   (0, 9377)	5
#   (0, 4567)	4
#   (0, 6743)	3
#   (0, 9881)	2108

# %%
, 'yeah': 12582, 'induced': 5664, 'pneumonia': 8744, 'everything': 4095, 'else': 3796, 'under': 11771, 'effects': 3708, 'penalty': 8509, 'kick': 6288, 'rashadiskandrni': 9412, 'experts': 4165, 'expanding': 4151, 'boost': 1591, 'regional': 9564, 'economies': 3673, 'during': 3596, 'recovery': 9528, 'public': 9155, 'amp': 783, 'private': 8995, 'sector': 10150, 'leaders': 6530, 'discus': 3334, 'reminds': 9607, 'some': 10552, 'believed': 1371, 'started': 10701, 'from': 4605, 'releasing': 9593, 'irwciyabve': 5888, 'if': 5470, 'see': 10155, 'an': 794, 'twitter': 11686, 'look': 6754, 'beneath': 1384, 'front': 4606, 'page': 8340, 'propaganda': 9060, 'truth': 11610, 'comments': 2325, 'pi': 8621, 'wayfairgate': 12281, 'glqbgszim5': 4863, 'via': 12050, 'r9xzbouoc1': 9351, 'part': 8401, 'deux': 3209, 'release': 9591, '16': 51, 'means': 7130, 'by': 1779, 'forbes': 4512, 'xevn2ppcun': 12534, 'iiot': 5498, 'iot': 5871, 'ai': 612, 'covid__19': 2669, 'business': 1761, 'digitaltransformation': 3293, 'cc': 1976, 'mvollmer1': 7609, 'treasadovander': 11561, 'sallye': 9968, 'davidcrz02': 2955, 'si': 10346, 'aquí': 962, 'gran': 4941, 'putas': 9198, 'estar': 4024, 'sabiendo': 9937, 'britany': 1674, 'para': 83 ...

# %%
# The raw data is hard to read, so here's a bit of prettifying code
feature_names = count_vect.get_feature_names()
sort_words_by_count(word_counts, feature_names)
# Out:
#                 count
# covid            3173
# 5g               2953
# rt               2108
# the              1837
# 19               1710
# de               1181
# co               1175
# https            1039
# to               1009
# and               935
# is                793
# of                783
# con               783
# you               679
# que               678
# in                657
# la                560
# it                548
# el                512
# del               496
# that              493
# los               484
# for               421
# are               400
# no                384
# on                357
# with              324
# gates             302
# bill              297
# las               269
# ...               ...
# implantar           1
# implanting          1
# imdrw               1
# implantée           1
# implement           1
# impli               1
# implica             1
# implicaciones       1
# implication         1
# implications        1
# imperative          1
# impeachqueen        1
# impazzire           1
# impattano           1
# imho                1
# imkimaaron          1
# immaginate          1
# immediately         1
# immense             1
# immer               1
# imminent            1
# immuned             1
# immunförsvaret      1
# immuno              1
# imo                 1
# impacta             1
# impactado           1
# impacting           1
# impacts             1
# 𝗽𝗿𝗼𝘃𝗮               1
#
# [13168 rows x 1 columns]

# %% [markdown]
# ## Take out stopwords
#
# 'to', 'and', 'is' etc don't add much to the data. We can remove them
#
# Also we can use our own stopwords, e.g.
#
# from sklearn.feature_extraction import text
# my_stop_words = text.ENGLISH_STOP_WORDS.union(my_words)
#
# vectorizer = TfidfVectorizer(analyzer=u'word',max_df=0.95,lowercase=True,stop_words=set(my_stop_words),max_features=15000)
# X= vectorizer.fit_transform(text)

# %%
from sklearn.feature_extraction import text
xxx = list(text.ENGLISH_STOP_WORDS)
xxx.sort()
print('{}'.format(xxx))
# Out:
# ['a', 'about', 'above', 'across', 'after', 'afterwards', 'again', 'against', 'all', 'almost', 'alone', 'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'amoungst', 'amount', 'an', 'and', 'another', 'any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere', 'are', 'around', 'as', 'at', 'back', 'be', 'became', 'because', 'become', 'becomes', 'becoming', 'been', 'before', 'beforehand', 'behind', 'being', 'below', 'beside', 'besides', 'between', 'beyond', 'bill', 'both', 'bottom', 'but', 'by', 'call', 'can', 'cannot', 'cant', 'co', 'con', 'could', 'couldnt', 'cry', 'de', 'describe', 'detail', 'do', 'done', 'down', 'due', 'during', 'each', 'eg', 'eight', 'either', 'eleven', 'else', 'elsewhere', 'empty', 'enough', 'etc', 'even', 'ever', 'every', 'everyone', 'everything', 'everywhere', 'except', 'few', 'fifteen', 'fifty', 'fill', 'find', 'fire', 'first', 'five', 'for', 'former', 'formerly', 'forty', 'found', 'four', 'from', 'front', 'full', 'further', 'get', 'give', 'go', 'had', 'has', 'hasnt', 'have', 'he', 'hence', 'her', 'here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers', 'herself', 'him', 'himself', 'his', 'how', 'however', 'hundred', 'i', 'ie', 'if', 'in', 'inc', 'indeed', 'interest', 'into', 'is', 'it', 'its', 'itself', 'keep', 'last', 'latter', 'latterly', 'least', 'less', 'ltd', 'made', 'many', 'may', 'me', 'meanwhile', 'might', 'mill', 'mine', 'more', 'moreover', 'most', 'mostly', 'move', 'much', 'must', 'my', 'myself', 'name', 'namely', 'neither', 'never', 'nevertheless', 'next', 'nine', 'no', 'nobody', 'none', 'noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of', 'off', 'often', 'on', 'once', 'one', 'only', 'onto', 'or', 'other', 'others', 'otherwise', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 'part', 'per', 'perhaps', 'please', 'put', 'rather', 're', 'same', 'see', 'seem', 'seemed', 'seeming', 'seems', 'serious', 'several', 'she', 'should', 'show', 'side', 'since', 'sincere', 'six', 'sixty', 'so', 'some', 'somehow', 'someone', 'something', 'sometime', 'sometimes', 'somewhere', 'still', 'such', 'system', 'take', 'ten', 'than', 'that', 'the', 'their', 'them', 'themselves', 'then', 'thence', 'there', 'thereafter', 'thereby', 'therefore', 'therein', 'thereupon', 'these', 'they', 'thick', 'thin', 'third', 'this', 'those', 'though', 'three', 'through', 'throughout', 'thru', 'thus', 'to', 'together', 'too', 'top', 'toward', 'towards', 'twelve', 'twenty', 'two', 'un', 'under', 'until', 'up', 'upon', 'us', 'very', 'via', 'was', 'we', 'well', 'were', 'what', 'whatever', 'when', 'whence', 'whenever', 'where', 'whereafter', 'whereas', 'whereby', 'wherein', 'whereupon', 'wherever', 'whether', 'which', 'while', 'whither', 'who', 'whoever', 'whole', 'whom', 'whose', 'why', 'will', 'with', 'within', 'without', 'would', 'yet', 'you', 'your', 'yours', 'yourself', 'yourselves']

# %%
count_vect = CountVectorizer(stop_words='english')
word_counts = count_vect.fit_transform(alltext)
feature_names = count_vect.get_feature_names()
sort_words_by_count(word_counts, feature_names)[:20]
# Out:
#             count
# covid        3173
# 5g           2953
# rt           2108
# 19           1710
# https        1039
# que           678
# la            560
# el            512
# del           496
# los           484
# gates         302
# las           269
# 4g            265
# da            264
# conspiracy    253
# cáncer        251
# people        244
# virus         237
# amp           232
# en            223

# %% [markdown]
# ## Look at bigrams
#
# * Bigram = pair of words
# * Trigram = sometimes three words together, but usually means three letters together (used to help with spelling differences etc)

# %%
count_vect = CountVectorizer(ngram_range =(2, 2))
word_counts = count_vect.fit_transform(alltext)
sort_words_by_count(word_counts, count_vect.get_feature_names())
# Out:
#                        count
# covid 19                1690
# https co                1028
# con covid                582
# bill gates               289
# venezuela diosdado       193
# los del                  193
# cabello con              193
# añez con                 193
# 19 los                   193
# diosdado cabello         193
# 19 bolivia               193
# brasil jair              193
# bolsonaro con            193
# bolivia jeanine          193
# jair bolsonaro           193
# jeanine añez             193
# 19 venezuela             193
# rt jmkarg                192
# del obelisc              192
# jmkarg brasil            192
# cobrem seu               175
# rosto dos                175
# comunista chinesa        175
# programas de             175
# também bloqueiam         175
# reconhecimento facial    175
# máscaras cobrem          175
# chinesa também           175
# bloqueiam sinais         175
# dos programas            175
# ...                      ...
# in harsh                   1
# in headlines               1
# anos na                    1
# in heavily                 1
# annual report              1
# in keynote                 1
# in kenya                   1
# annual summit              1
# ano do                     1
# in july                    1
# in jersey                  1
# in january                 1
# in jan                     1
# in its                     1
# in italia                  1
# in it                      1
# ano equivaleu              1
# in international           1
# in inside                  1
# anon corona                1
# in illuminatedark8         1
# in hypoxia                 1
# in humanity                1
# anonymoussage1 it          1
# in how                     1
# in hongkong                1
# in het                     1
# in her                     1
# in hele                    1
# 𝗽𝗿𝗼𝘃𝗮 𝗴𝗿𝗮𝘁𝘂𝗶𝘁𝗮             1
#
# [37150 rows x 1 columns]

# %% [markdown]
# ## Look at text per tweet

# %%
# Let's count up the words in each tweet
count_vect = CountVectorizer()
word_counts = count_vect.fit_transform(df['text'])

print('{}'.format(word_counts))
# Out:
#   (0, 3830)	1
#   (0, 11759)	1
#   (0, 8402)	1
#   (0, 4528)	1
#   (0, 2657)	1
#   (0, 3737)	1
#   (0, 10225)	1
#   (0, 2983)	2
#   (0, 3731)	1
#   (0, 11432)	1
#   (0, 3993)	1
#   (0, 6768)	2
#   (0, 8762)	1
#   (0, 12558)	1
#   (0, 11002)	1
#   (0, 9172)	1
#   (0, 9377)	1
#   (0, 4567)	1
#   (0, 6743)	1
#   (0, 9881)	1
#   (1, 427)	1
#   (1, 1844)	1
#   (1, 12611)	1
#   (1, 815)	1
#   (1, 10302)	1
#   :	:
#   (3832, 3988)	1
#   (3832, 11007)	1
#   (3832, 4050)	1
#   (3832, 1960)	1
#   (3832, 8504)	1
#   (3832, 1798)	1
#   (3832, 5517)	1
#   (3832, 3800)	1
#   (3832, 2307)	1
#   (3832, 12049)	1
#   (3832, 877)	1
#   (3832, 7658)	1
#   (3832, 8370)	2
#   (3832, 8354)	1
#   (3832, 7871)	1
#   (3832, 7124)	1
#   (3832, 1025)	1
#   (3832, 3934)	1
#   (3832, 9282)	2
#   (3832, 244)	2
#   (3832, 2657)	1
#   (3832, 2983)	1
#   (3833, 2849)	1
#   (3833, 2261)	1
#   (3833, 5363)	1

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tf_transformer = TfidfTransformer(use_idf=True)
tf_features = tf_transformer.fit_transform(word_counts)
print('{}'.format(tf_features))

# %% [markdown]
# # Named Entity Recognition
#
# You'll need to both pip install spacy and also do
#
# python -m spacy download en_core_web_sm

# %%
import spacy
nlp = spacy.load('en_core_web_sm') 
  
sentence = "Bill Gates lives near Seattle"
doc = nlp(sentence) 
for ent in doc.ents: 
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Bill Gates 0 10 PERSON
# Seattle 22 29 GPE
